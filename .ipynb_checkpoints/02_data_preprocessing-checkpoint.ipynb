# %% [markdown]
# # Preprocesado de datos
# ## Autor: Juan Carlos Alonso Valenzuela
# En este notebook se preprocesarán los datos extraídos de la API de Twitter para expresarlos en un formato que pueda ser leído como un grafo.

# %%
import pandas as pd
import re

# %% [markdown]
# # Carga de datos

# %% [markdown]
# Comenzamos leyendo los archivos

# %%
# Neutral
realMadridEspanyol = pd.read_csv('dataset/RealMadridEspanyol.csv')
# Madrid
CAMPEON35 = pd.read_csv('dataset/CAMPEON35.csv')
RMFans = pd.read_csv('dataset/RMFans.csv')
# Espanyol
RCDE = pd.read_csv('dataset/RCDE.csv')
planterRCDE = pd.read_csv('dataset/planterRCDE.csv')

# %% [markdown]
# Unimos todos los DataFrames en una sola variable

# %%
df = pd.concat([realMadridEspanyol,CAMPEON35,RMFans,RCDE,planterRCDE])
# Shuffle data
df = df.sample(frac=1.)

# Drop Unnamed column
df = df.drop(columns='Unnamed: 0')

# Reset index
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#            username                                      tweet_content  \
# 0         farahh_so  RT @LaLiga: 🎉🎊⚽ ¡@Benzema también se une a la ...
# 1   RubenMusic4ever  RT @realmadrid: 🙌 ¡#CAMPEON35 DE @LALIGA! 🙌\n🏁...
# 2    RCDEFutbolBase  90+4' | 2-2 | 🟥 Chico\n\n#RCDE | #planterRCDE ...
# 3       wantan_ver2  RT @realmadrid: #RMFans x Cibeles x #CAMPEON35...
# 4         Neiva8814  RT @realmadrid: 👋 ¡@RafaelNadal hizo el saque ...
# 5      sergiorello3  RT @SBlanquia: Quien te ha visto y quien te ve...
# 6          faxx2277  RT @realmadrid: 🤍 ¡NUESTRA DIOSA! 🤍\n#CAMPEON3...
# 7    RCDEFutbolBase  67' | 2-2 | Empata l'Ejea\n\n#RCDE | #planterRCDE
# 8      DonTxingurri  RT @OldRcd: Presentaciones de las alineaciones...
# 9   RubenMusic4ever  RT @realmadrid: ✨ ¡SIEMPRE EN MI EQUIPO! ✨\n#C...
# 10      wantan_ver2  RT @realmadrid: #RMFans x Cibeles x #CAMPEON35...
# 11      luisfwbiano  RT @realmadrid: #RMFans x Cibeles x #CAMPEON35...
# 12     AbdallahJR16  RT @realmadrid: La foto que necesitabais, #RMF...
# 13          mubyjay  RT @realmadriden: #RMFans x Cibeles x #CAMPEON...
# 14      RcdeOvunque  RT @OldRcd: Presentaciones de las alineaciones...
# 15  Margari99388494  RT @realmadrid: 👋 ¡@RafaelNadal hizo el saque ...
# 16   RCDEFutbolBase  90+1' | 2-2 | Canvi a la SD Ejea\n\n🔺 Dani Mar...
# 17      sergihio199  RT @RCDEFutbolBase: 67' | 2-2 | Empata l'Ejea\...
# 18      luisfwbiano  RT @realmadrid: #RMFans x Cibeles x #CAMPEON35...
# 19      sergihio199  RT @RCDEFutbolBase: 20' | 2-1 | Gol de la SD E...
# 20       JorgeAHB19  RT @rnmjtv2: Marcelo le pone la bufanda a la d...
# 21      proespanyol  Pues si es cierto, me parece una broma de mal ...
# 22         Tindef91  RT @Juvenil1991: Siempre supimos que el único ...
# 23    SaberiAfsaneh  RT @RNMJ_TV: Declaraciones de FLORENTINO PEREZ...
# 24          Davvonx  RT @realmadrid: #RMFans x Cibeles x #CAMPEON35...
#
#     n_favorites                       timestamp  \
# 0             0  Sat Apr 30 23:57:34 +0000 2022
# 1             0  Sat Apr 30 23:57:47 +0000 2022
# 2             0  Sat Apr 30 18:24:43 +0000 2022
# 3             0  Sat Apr 30 23:59:56 +0000 2022
# 4             0  Sat Apr 30 23:54:26 +0000 2022
# 5             0  Sat Apr 30 23:11:06 +0000 2022
# 6             0  Sat Apr 30 23:59:59 +0000 2022
# 7             0  Sat Apr 30 17:56:27 +0000 2022
# 8             0  Sat Apr 30 23:12:39 +0000 2022
# 9             0  Sat Apr 30 23:59:59 +0000 2022
# 10            0  Sat Apr 30 23:59:56 +0000 2022
# 11            0  Sat Apr 30 23:59:59 +0000 2022
# 12            0  Sat Apr 30 23:59:51 +0000 2022
# 13            0  Sat Apr 30 23:59:45 +0000 2022
# 14            0  Sat Apr 30 23:28:04 +0000 2022
# 15            0  Sat Apr 30 23:54:07 +0000 2022
# 16            2  Sat Apr 30 18:21:39 +0000 2022
# 17            0  Sat Apr 30 17:58:14 +0000 2022
# 18            0  Sat Apr 30 23:59:59 +0000 2022
# 19            0  Sat Apr 30 16:53:35 +0000 2022
# 20            0  Sat Apr 30 23:59:58 +0000 2022
# 21            0  Sat Apr 30 23:37:22 +0000 2022
# 22            0  Sat Apr 30 23:27:57 +0000 2022
# 23            0  Sat Apr 30 23:59:48 +0000 2022
# 24            0  Sat Apr 30 23:59:52 +0000 2022
#
#                                              mentions
# 0                 ['LaLiga', 'Benzema', 'realmadrid']
# 1   ['realmadrid', 'LaLiga', 'realmadrid', 'RCDEsp...
# 2                                                  []
# 3                                      ['realmadrid']
# 4                       ['realmadrid', 'RafaelNadal']
# 5                                       ['SBlanquia']
# 6                                      ['realmadrid']
# 7                                                  []
# 8                                          ['OldRcd']
# 9                                      ['realmadrid']
# 10                                     ['realmadrid']
# 11                                     ['realmadrid']
# 12                                     ['realmadrid']
# 13                                   ['realmadriden']
# 14                                         ['OldRcd']
# 15                      ['realmadrid', 'RafaelNadal']
# 16                                                 []
# 17                                 ['RCDEFutbolBase']
# 18                                     ['realmadrid']
# 19                                 ['RCDEFutbolBase']
# 20                                        ['rnmjtv2']
# 21                                                 []
# 22                                    ['Juvenil1991']
# 23                                        ['RNMJ_TV']
# 24                                     ['realmadrid']

# %% [markdown]
# Un tweet es un retweet si comienza con los caracteres "RT @" seguidos del nombre el usuario al que se está retweeteando.

# %%
tweet_content_values = df['tweet_content'].values.tolist()
rt_column = []

for tweet in tweet_content_values:
    rt_regex = re.compile(r"^RT\s@.[a-zA-Z0-9]+(?::)")
    
    if rt_regex.match(tweet):
        # The tweet is a retweet
        retweet_from = tweet.split(":")[0][4:]
        rt_column.append(retweet_from)
    else:
        # The tweet is not a retweet
        rt_column.append(None)

df['retweet'] = rt_column

# %%
df.head()
# Out:
#            username                                      tweet_content  \
# 0         farahh_so  RT @LaLiga: 🎉🎊⚽ ¡@Benzema también se une a la ...
# 1   RubenMusic4ever  RT @realmadrid: 🙌 ¡#CAMPEON35 DE @LALIGA! 🙌\n🏁...
# 2    RCDEFutbolBase  90+4' | 2-2 | 🟥 Chico\n\n#RCDE | #planterRCDE ...
# 3       wantan_ver2  RT @realmadrid: #RMFans x Cibeles x #CAMPEON35...
# 4         Neiva8814  RT @realmadrid: 👋 ¡@RafaelNadal hizo el saque ...
# 5      sergiorello3  RT @SBlanquia: Quien te ha visto y quien te ve...
# 6          faxx2277  RT @realmadrid: 🤍 ¡NUESTRA DIOSA! 🤍\n#CAMPEON3...
# 7    RCDEFutbolBase  67' | 2-2 | Empata l'Ejea\n\n#RCDE | #planterRCDE
# 8      DonTxingurri  RT @OldRcd: Presentaciones de las alineaciones...
# 9   RubenMusic4ever  RT @realmadrid: ✨ ¡SIEMPRE EN MI EQUIPO! ✨\n#C...
# 10      wantan_ver2  RT @realmadrid: #RMFans x Cibeles x #CAMPEON35...
# 11      luisfwbiano  RT @realmadrid: #RMFans x Cibeles x #CAMPEON35...
# 12     AbdallahJR16  RT @realmadrid: La foto que necesitabais, #RMF...
# 13          mubyjay  RT @realmadriden: #RMFans x Cibeles x #CAMPEON...
# 14      RcdeOvunque  RT @OldRcd: Presentaciones de las alineaciones...
# 15  Margari99388494  RT @realmadrid: 👋 ¡@RafaelNadal hizo el saque ...
# 16   RCDEFutbolBase  90+1' | 2-2 | Canvi a la SD Ejea\n\n🔺 Dani Mar...
# 17      sergihio199  RT @RCDEFutbolBase: 67' | 2-2 | Empata l'Ejea\...
# 18      luisfwbiano  RT @realmadrid: #RMFans x Cibeles x #CAMPEON35...
# 19      sergihio199  RT @RCDEFutbolBase: 20' | 2-1 | Gol de la SD E...
# 20       JorgeAHB19  RT @rnmjtv2: Marcelo le pone la bufanda a la d...
# 21      proespanyol  Pues si es cierto, me parece una broma de mal ...
# 22         Tindef91  RT @Juvenil1991: Siempre supimos que el único ...
# 23    SaberiAfsaneh  RT @RNMJ_TV: Declaraciones de FLORENTINO PEREZ...
# 24          Davvonx  RT @realmadrid: #RMFans x Cibeles x #CAMPEON35...
#
#     n_favorites                       timestamp  \
# 0             0  Sat Apr 30 23:57:34 +0000 2022
# 1             0  Sat Apr 30 23:57:47 +0000 2022
# 2             0  Sat Apr 30 18:24:43 +0000 2022
# 3             0  Sat Apr 30 23:59:56 +0000 2022
# 4             0  Sat Apr 30 23:54:26 +0000 2022
# 5             0  Sat Apr 30 23:11:06 +0000 2022
# 6             0  Sat Apr 30 23:59:59 +0000 2022
# 7             0  Sat Apr 30 17:56:27 +0000 2022
# 8             0  Sat Apr 30 23:12:39 +0000 2022
# 9             0  Sat Apr 30 23:59:59 +0000 2022
# 10            0  Sat Apr 30 23:59:56 +0000 2022
# 11            0  Sat Apr 30 23:59:59 +0000 2022
# 12            0  Sat Apr 30 23:59:51 +0000 2022
# 13            0  Sat Apr 30 23:59:45 +0000 2022
# 14            0  Sat Apr 30 23:28:04 +0000 2022
# 15            0  Sat Apr 30 23:54:07 +0000 2022
# 16            2  Sat Apr 30 18:21:39 +0000 2022
# 17            0  Sat Apr 30 17:58:14 +0000 2022
# 18            0  Sat Apr 30 23:59:59 +0000 2022
# 19            0  Sat Apr 30 16:53:35 +0000 2022
# 20            0  Sat Apr 30 23:59:58 +0000 2022
# 21            0  Sat Apr 30 23:37:22 +0000 2022
# 22            0  Sat Apr 30 23:27:57 +0000 2022
# 23            0  Sat Apr 30 23:59:48 +0000 2022
# 24            0  Sat Apr 30 23:59:52 +0000 2022
#
#                                              mentions         retweet
# 0                 ['LaLiga', 'Benzema', 'realmadrid']          LaLiga
# 1   ['realmadrid', 'LaLiga', 'realmadrid', 'RCDEsp...      realmadrid
# 2                                                  []            None
# 3                                      ['realmadrid']      realmadrid
# 4                       ['realmadrid', 'RafaelNadal']      realmadrid
# 5                                       ['SBlanquia']       SBlanquia
# 6                                      ['realmadrid']      realmadrid
# 7                                                  []            None
# 8                                          ['OldRcd']          OldRcd
# 9                                      ['realmadrid']      realmadrid
# 10                                     ['realmadrid']      realmadrid
# 11                                     ['realmadrid']      realmadrid
# 12                                     ['realmadrid']      realmadrid
# 13                                   ['realmadriden']    realmadriden
# 14                                         ['OldRcd']          OldRcd
# 15                      ['realmadrid', 'RafaelNadal']      realmadrid
# 16                                                 []            None
# 17                                 ['RCDEFutbolBase']  RCDEFutbolBase
# 18                                     ['realmadrid']      realmadrid
# 19                                 ['RCDEFutbolBase']  RCDEFutbolBase
# 20                                        ['rnmjtv2']         rnmjtv2
# 21                                                 []            None
# 22                                    ['Juvenil1991']     Juvenil1991
# 23                                        ['RNMJ_TV']            None
# 24                                     ['realmadrid']      realmadrid
