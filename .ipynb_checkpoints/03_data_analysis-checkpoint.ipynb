# %% [markdown]
# # Análisis de los datos
# ## Autor: Juan Carlos Alonso Valenzuela

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset/dataset_edges.csv')

# %%
df.head()
# Out:
#    AbdallahJR16  realmadrid  1.0
# 0       Davvonx  realmadrid  1.0
# 1  DonTxingurri      OldRcd  1.0
# 2    JorgeAHB19     rnmjtv2  1.0
# 3   Juvenil1991    Tindef91  1.0
# 4        LaLiga   farahh_so  1.0

# %%
graph = nx.read_edgelist("dataset/dataset_edges.csv", delimiter=",", data=[("weight", float)])

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 30))
nx.draw_networkx(graph, with_labels=False,
                 ax=ax, 
                 node_size=50,
                 font_size=10, 
                 alpha=.5)

ax.set_axis_off()
